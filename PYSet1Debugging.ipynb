# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def add_numbers(a, b):
    return a + b

# %%
add_numbers(3,4)
# Out:
# 7

# %%
a="10"
b="5"
print(a+b)
# Out:
# 105

# %%
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %%
x = 5/0 
#Zero division error

# %%
name ="Alice"
age = 25
print("Name: ",name + ", Age: ",age)
# Out:
# Name:  Alice, Age:  25
