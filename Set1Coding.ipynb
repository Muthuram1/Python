# %%
print(*range(1,6))
# Out:
# 1 2 3 4 5

# %%
print(*range(2,11,2))
# Out:
# 2 4 6 8 10

# %%
totSum=sum(range(1,11))
print(totSum)
# Out:
# 55

# %%
import math
fac=(math.factorial(5))
print(fac)
# Out:
# 120

# %%
num=int(input("Enter a number:"))
for i in range(2,num):
    if(num % i == 0):
        print(num,"is not a prime number")
        break
    else:
        print(num,"is a prime number")
        break
# Out:
# Enter a number: 7
# 7 is a prime number
